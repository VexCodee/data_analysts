# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/CO2_Emissions_1960-2018.csv")
df_world = df[df['country']=='World']
df_world
# Out:
#     country      1960     1961      1962      1963      1964      1965  \
# 259   World  3.121158  3.06809  3.114839  3.221195  3.324046  3.432395
#
#          1966      1967      1968  ...      2009      2010      2011  \
# 259  3.534191  3.585995  3.704543  ...  4.277131  4.483148  4.570123
#
#          2012      2013      2014     2015      2016      2017      2018
# 259  4.578768  4.610229  4.560774  4.48877  4.436759  4.441309  4.483524
#
# [1 rows x 60 columns]

# %%
df_transpose = df_world.T
df_transpose
# Out:
#               259
# country     World
# 1960     3.121158
# 1961      3.06809
# 1962     3.114839
# 1963     3.221195
# 1964     3.324046
# 1965     3.432395
# 1966     3.534191
# 1967     3.585995
# 1968     3.704543
# 1969     3.875169
# 1970     4.147851
# 1971     4.231788
# 1972     4.347295
# 1973     4.493253
# 1974     4.403582
# 1975     4.342629
# 1976     4.493091
# 1977     4.558983
# 1978     4.653016
# 1979     4.696086
# 1980     4.601082
# 1981     4.406638
# 1982      4.31496
# 1983     4.286135
# 1984     4.339077
# 1985     4.428312
# 1986     4.412252
# 1987     4.461923
# 1988     4.565403
# 1989     4.566474
# 1990     3.902964
# 1991     3.874591
# 1992     3.804011
# 1993     3.769328
# 1994     3.732385
# 1995     3.781982
# 1996     3.806694
# 1997     3.813515
# 1998     3.780611
# 1999     3.747766
# 2000     3.812649
# 2001     3.827659
# 2002     3.834751
# 2003     3.958503
# 2004     4.092252
# 2005     4.196301
# 2006     4.281006
# 2007     4.391867
# ...

# %%
df_transpose.columns=df_transpose.iloc[0]
df_transpose=df_transpose.drop(labels='country', axis=0)

# %%
df_transpose.columns=['index']
df_transpose.reset_index(inplace=True)

# %%
df_transpose['level_0']=pd.to_datetime(df_transpose['level_0'])
df_transpose.columns=['year', 'emissions']

# %%
df_transpose
# Out:
#          year emissions
# 0  1960-01-01  3.121158
# 1  1961-01-01   3.06809
# 2  1962-01-01  3.114839
# 3  1963-01-01  3.221195
# 4  1964-01-01  3.324046
# 5  1965-01-01  3.432395
# 6  1966-01-01  3.534191
# 7  1967-01-01  3.585995
# 8  1968-01-01  3.704543
# 9  1969-01-01  3.875169
# 10 1970-01-01  4.147851
# 11 1971-01-01  4.231788
# 12 1972-01-01  4.347295
# 13 1973-01-01  4.493253
# 14 1974-01-01  4.403582
# 15 1975-01-01  4.342629
# 16 1976-01-01  4.493091
# 17 1977-01-01  4.558983
# 18 1978-01-01  4.653016
# 19 1979-01-01  4.696086
# 20 1980-01-01  4.601082
# 21 1981-01-01  4.406638
# 22 1982-01-01   4.31496
# 23 1983-01-01  4.286135
# 24 1984-01-01  4.339077
# 25 1985-01-01  4.428312
# 26 1986-01-01  4.412252
# 27 1987-01-01  4.461923
# 28 1988-01-01  4.565403
# 29 1989-01-01  4.566474
# 30 1990-01-01  3.902964
# 31 1991-01-01  3.874591
# 32 1992-01-01  3.804011
# 33 1993-01-01  3.769328
# 34 1994-01-01  3.732385
# 35 1995-01-01  3.781982
# 36 1996-01-01  3.806694
# ...

# %%
df_transpose.plot(x='year', y='emissions', kind='line')
plt.show()

# %%
# !pip3 install openpyxl
# Out:
# ...
#   Using cached openpyxl-3.0.10-py2.py3-none-any.whl (242 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
df_transpose.to_excel('world_emision.xlsx')
